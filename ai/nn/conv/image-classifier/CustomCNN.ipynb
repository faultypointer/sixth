# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F 
from torchvision import datasets, transforms
import os

print(torch.__version__)
# Out:
# 2.5.0.dev20240708

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
print(f"Using device = ",device)
# Out:
# Using device =  mps

# %%
# Define dataset paths
train_dir = "CustomDataSet/data/train"
test_dir = "CustomDataSet/data/test"

# %%
# Define train and test transforms
train_transform = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=20),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomGrayscale(p=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5))
])

# %%
# Load datasets
train_data = datasets.ImageFolder(root=train_dir, transform=train_transform)
test_data = datasets.ImageFolder(root=test_dir, transform=test_transform)

# %%
# Create dataloaders
batch_size = 32
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
from model import CustomCNN

# %%
model_0 = CustomCNN(num_classes=4)
model_0.to(device)
# Out:
# CustomCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=32768, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
class_names = train_data.classes
class_names
# Out:
# ['donuts', 'french_fries', 'fried_rice', 'samosa']

# %%
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'donuts': 0, 'french_fries': 1, 'fried_rice': 2, 'samosa': 3}

# %%
len(train_data), len(test_data)
# Out:
# (1834, 608)

# %%
from torchinfo import summary

summary(model=model_0,
        input_size=(32,3,128,128),
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# CustomCNN (CustomCNN)                    [32, 3, 128, 128]    [32, 4]              --                   True
# ├─Conv2d (conv1)                         [32, 3, 128, 128]    [32, 32, 128, 128]   896                  True
# ├─ReLU (relu)                            [32, 32, 128, 128]   [32, 32, 128, 128]   --                   --
# ├─MaxPool2d (pool)                       [32, 32, 128, 128]   [32, 32, 64, 64]     --                   --
# ├─Conv2d (conv2)                         [32, 32, 64, 64]     [32, 64, 64, 64]     18,496               True
# ├─ReLU (relu)                            [32, 64, 64, 64]     [32, 64, 64, 64]     --                   --
# ├─MaxPool2d (pool)                       [32, 64, 64, 64]     [32, 64, 32, 32]     --                   --
# ├─Conv2d (conv3)                         [32, 64, 32, 32]     [32, 128, 32, 32]    73,856               True
# ├─ReLU (relu)                            [32, 128, 32, 32]    [32, 128, 32, 32]    --                   --
# ├─MaxPool2d (pool)                       [32, 128, 32, 32]    [32, 128, 16, 16]    --                   --
# ├─Linear (fc1)                           [32, 32768]          [32, 512]            16,777,728           True
# ├─ReLU (relu)                            [32, 512]            [32, 512]            --                   --
# ├─Linear (fc2)                           [32, 512]            [32, 4]              2,052                True
# ========================================================================================================================
# Total params: 16,873,028
# Trainable params: 16,873,028
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 5.85
# ========================================================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 235.01
# Params size (MB): 67.49
# Estimated Total Size (MB): 308.80
# ========================================================================================================================

# %%
# Setup loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_0.parameters(), lr=0.001, weight_decay=1e-4)

# %%
from trainNN import train

torch.manual_seed(42)
torch.cuda.manual_seed(42)

from timeit import default_timer as timer
start_time = timer()

results = train(
            model=model_0,
            train_dataloader=train_loader,
            test_dataloader=test_loader,
            optimizer=optimizer,
            loss_fn=criterion,
            epochs=20,
            device=device
)

end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.3842 | train_acc: 0.3159 | test_loss: 1.3062 | test_acc: 0.3684
# Epoch: 2 | train_loss: 1.3041 | train_acc: 0.3634 | test_loss: 1.2355 | test_acc: 0.4408
# Epoch: 3 | train_loss: 1.2687 | train_acc: 0.4019 | test_loss: 1.1606 | test_acc: 0.5132
# Epoch: 4 | train_loss: 1.2209 | train_acc: 0.4376 | test_loss: 1.1319 | test_acc: 0.5280
# Epoch: 5 | train_loss: 1.2046 | train_acc: 0.4372 | test_loss: 1.1692 | test_acc: 0.4786
# Epoch: 6 | train_loss: 1.1832 | train_acc: 0.4767 | test_loss: 1.1158 | test_acc: 0.5576
# Epoch: 7 | train_loss: 1.1522 | train_acc: 0.4890 | test_loss: 1.0368 | test_acc: 0.5740
# Epoch: 8 | train_loss: 1.1441 | train_acc: 0.4962 | test_loss: 1.0610 | test_acc: 0.5839
# Epoch: 9 | train_loss: 1.0776 | train_acc: 0.5356 | test_loss: 0.9915 | test_acc: 0.6151
# Epoch: 10 | train_loss: 1.0620 | train_acc: 0.5654 | test_loss: 1.0137 | test_acc: 0.5905
# Epoch: 11 | train_loss: 1.0264 | train_acc: 0.5653 | test_loss: 0.9895 | test_acc: 0.5839
# Epoch: 12 | train_loss: 1.0246 | train_acc: 0.5636 | test_loss: 1.0385 | test_acc: 0.5872
# Epoch: 13 | train_loss: 0.9645 | train_acc: 0.6064 | test_loss: 0.8942 | test_acc: 0.6612
# Epoch: 14 | train_loss: 0.9523 | train_acc: 0.6085 | test_loss: 0.8786 | test_acc: 0.6530
# Epoch: 15 | train_loss: 0.9530 | train_acc: 0.6102 | test_loss: 0.8528 | test_acc: 0.6793
# Epoch: 16 | train_loss: 0.9306 | train_acc: 0.6208 | test_loss: 0.8209 | test_acc: 0.6793
# Epoch: 17 | train_loss: 0.8803 | train_acc: 0.6543 | test_loss: 0.8336 | test_acc: 0.6891
# Epoch: 18 | train_loss: 0.8685 | train_acc: 0.6498 | test_loss: 0.8929 | test_acc: 0.6579
# Epoch: 19 | train_loss: 0.8984 | train_acc: 0.6275 | test_loss: 0.8378 | test_acc: 0.6842
# Epoch: 20 | train_loss: 0.8463 | train_acc: 0.6566 | test_loss: 0.8087 | test_acc: 0.7039
# [INFO] Total training time: 253.601 seconds

# %%
from helper_functions import plot_loss_curves
plot_loss_curves(results)

# %%
from pathlib import Path

MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)
MODEL_NAME = "modelv0.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME
print(f"Saving model to {MODEL_SAVE_PATH}")
torch.save(obj=model_0.state_dict(), f=MODEL_SAVE_PATH)
# Out:
# Saving model to models/modelv0.pth
